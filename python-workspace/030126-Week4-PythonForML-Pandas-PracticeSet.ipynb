# %%
import numpy as np
np.random.randn(6,4)
# Out:
# array([[ 2.89256081, -0.51804768,  0.64640121,  1.87108003],
#        [ 0.70906218,  0.06801492,  2.14393617, -2.06162513],
#        [ 0.26031511,  0.47516474, -0.22910121, -0.03633082],
#        [ 0.00863075,  0.22416304,  0.60610588, -1.30972107],
#        [ 0.42175323, -1.44185537,  0.49528045, -1.00466426],
#        [ 0.44413483, -1.75600008, -0.71293556, -2.17333283]])
